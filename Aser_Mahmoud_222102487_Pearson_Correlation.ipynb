# %% [markdown]
# # Name: **Aser Mohamed Ali Mahmoud**
# # ID: **222102487**
# # Program: **AIS**

# %% [markdown]
# # Course Code: **AIE425**
# # Course Name: **Intelligent Recommender Systems**

# %% [markdown]
# # **Lab (3) Task**
# # **Pearson Correlation Implementation**

# %%
import numpy as np

def pearson_correlation(user1, user2):
    """Calculate Pearson correlation between two users"""
    # Get common rated items
    mask = (user1 != 0) & (user2 != 0)

    if not np.any(mask):
        return 0

    u1 = user1[mask]
    u2 = user2[mask]

    # Calculate means
    mean1 = np.mean(u1)
    mean2 = np.mean(u2)

    # Calculate deviations
    dev1 = u1 - mean1
    dev2 = u2 - mean2
import numpy as np

def pearson_correlation(user1, user2):
    """Calculate Pearson correlation between two users"""
    # Get common rated items
    mask = (user1 != 0) & (user2 != 0)

    if not np.any(mask):
        return 0

    u1 = user1[mask]
    u2 = user2[mask]

    # Calculate means
    mean1 = np.mean(u1)
    mean2 = np.mean(u2)

    # Calculate deviations
    dev1 = u1 - mean1
    dev2 = u2 - mean2

    # Calculate numerator
    numerator = np.sum(dev1 * dev2)

    # Calculate denominator
    denominator = np.sqrt(np.sum(dev1**2)) * np.sqrt(np.sum(dev2**2))

    if denominator == 0:
        return 0

    return numerator / denominator


# Example usage
user_A = np.array([5, 3, 0, 4, 0, 2])
user_C = np.array([4, 3, 4, 3, 5, 3])

correlation = pearson_correlation(user_A, user_C)
print(f"Pearson Correlation: {correlation:.3f}")
# Output: Pearson Correlation: 0.775
# Out:
# Pearson Correlation: 0.775

# %% [markdown]
# # Under the Supervision of: **Prof. Samy & Eng. Salama**
